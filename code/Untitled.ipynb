# %%
import pandas as pd; df = pd.read_csv('/Users/ibrahim/Coverage/code/core.txt', sep='\t').set_index('gene_callers_id')

# %%
df
# Out:
#                  ANE_004_05M  ANE_004_40M  ANE_150_05M  ANE_150_05M_MT  \
# gene_callers_id
# 1230                0.000000     0.000000     0.701389        0.000000
# 1231                0.000000     0.779553     1.075638        0.000000
# 1232                2.308204     8.848606     0.800000        0.011673
# 1233                0.000000     0.000000     1.673582        0.000000
# 1234                0.370583     1.080229     1.181025        0.000000
# ...                      ...          ...          ...             ...
# 2697               94.403433   163.625920   191.183499        0.000000
# 2698               79.135802    98.962963   106.032099        0.000000
# 2699                1.140036     3.108664     1.180617        0.000000
# 29728             460.275949   477.937019   425.980569        0.000000
# 29729             135.914219   165.365909   152.231431        0.000000
#
#                  ANE_150_40M  ANE_150_40M_MT  ANE_151_05M  ANE_151_05M_MT  \
# gene_callers_id
# ...

# %%
from probability import Values as V

# %%
v = V()

# %%
core = v.core_dataframe/v.core_dataframe.sum()

# %%
import seaborn as sns

# %%
g = sns.histplot(core, kde = False, color ='red')
g.set(ylim=(0,1))
# Out:
# [(0, 1)]
